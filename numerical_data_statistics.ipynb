# %% [markdown]
# <a href="https://colab.research.google.com/github/Oliwash254/machine-learning/blob/main/numerical_data_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas~=2.2.0 \
matplotlib~=3.10.0
from matplotlib import pyplot as plt
import io
import pandas as pd
#the following lines adjust the garnularity of reporting.
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format
from google.colab import files
uploaded=files.upload()
# Out:
# ...
#      <input type="file" id="files-50be3bcf-85dc-4112-8daf-f3addb5cd7d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50be3bcf-85dc-4112-8daf-f3addb5cd7d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#import the dataset
training_df = pd.read_csv('california_housing_train.csv')

# %%
#get basic statistics
training_df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# ...

# %% [markdown]
# #**identify outlier**

# %% [markdown]
# **defining plotting functions**

# %%
#@title Define the plotting functions { display-mode: "form" }

# The following code defines the plotting functions that can be used to
# visualize the data.

def plot_the_dataset(feature, label, number_of_points_to_plot):
  """Plot N random points of the dataset."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from n random points of the dataset.
  random_examples = training_df.sample(n=number_of_points_to_plot)
  plt.scatter(random_examples[feature], random_examples[label])

  # Render the scatter plot.
  plt.show()

def plot_a_contiguous_portion_of_dataset(feature, label, start, end):
  """Plot the data points from start to end."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot.
  plt.scatter(training_df[feature][start:end], training_df[label][start:end])

  # Render the scatter plot.
  plt.show()


print("Defined the following functions:")
print("  * plot_the_dataset")
print("  * plot_a_contiguous_portion_of_dataset")
# Out:
# Defined the following functions:
#   * plot_the_dataset
#   * plot_a_contiguous_portion_of_dataset

# %% [markdown]
# *visualize the dataset*

# %%
plot_the_dataset("longitude", "latitude", 100)
plot_the_dataset("housing_median_age", "median_house_value", 100)
plot_the_dataset("total_rooms", "total_bedrooms", 100)
plot_the_dataset("population", "households", 100)
plot_the_dataset("median_income", "median_house_value", 100)

# %% [markdown]
# get statistics

# %%
training_df[0:350].describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count      350.0     350.0               350.0        350.0           350.0
# mean      -116.1      33.5                18.9       3143.7           667.5
# std          0.6       0.6                 9.0       2998.4           616.2
# min       -116.9      32.6                 2.0         42.0            10.0
# 25%       -116.6      32.9                13.0       1203.2           268.0
# 50%       -116.3      33.6                17.0       2232.0           476.0
# 75%       -115.6      33.8                24.0       4119.0           849.0
# max       -114.3      36.0                52.0      19107.0          3923.0
#
#        population  households  median_income  median_house_value
# count       350.0       350.0          350.0               350.0
# mean       1365.2       480.9            2.9            111184.6
# std        1120.5       397.7            1.4             72180.3
# ...

# %%
for i in range(0,7):
  start = i*50
  end = start + 49
  plot_a_contiguous_portion_of_dataset("households", "population", start, end)
